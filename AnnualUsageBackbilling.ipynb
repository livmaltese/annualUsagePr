# %%
import pandas as pd

# %%
df_daily = pd.read_csv("daily_data_noram.csv")
df_monthly = pd.read_csv("monthly_data_noram.csv")

# %%
df_daily.head()
df_monthly.head()
# Out:
#                         customer_id                            customer_name  \
# 0  F0EF41DB74F14450A97D2F997F69161B           Colonial Country Club - GLOBAL
# 1  4F79E560548C40352C720AF6E44EEF6D  Coach Atlantic Transportation Group Inc
# 2  FB1D206C3AB548088FF3A470913BF196             Caffe Artigiano Inc - GLOBAL
# 3  54EC71205B554AEB856813A04969171B                        Lupton QB Online.
# 4  30EF1BB4DB8D40288510A791AEE403E1                          Waites - GLOBAL
#
#    invoice_cnt salesforceaccountid salesforcelegalentityid report_date  \
# 0            1  001OL00000Qu4TNYAZ      a12OL00000NIHA1YAP  2026-01-01
# 1            1  0011H000023uIEdQAM      a12OL00000N31WzYAJ  2026-01-01
# 2            1  001OL00000RWisnYAD      a12OL00000NCltxYAD  2026-01-01
# 3            1  0011200001GicZ1AAJ      a12OL00000N8mjrYAB  2026-01-01
# 4            7  001OL00000dQF8EYAW      a12OL00000N0SS5YAN  2026-01-01
#
#   frequency
# 0   monthly
# 1   monthly
# 2   monthly
# 3   monthly
# ...
